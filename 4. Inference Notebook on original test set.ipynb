# %% [markdown]
# ### Important libraries

# %%
import time
from pathlib import Path
import os

import cv2
import torch
from numpy import random
import pandas as pd
import numpy as np

from models.experimental import attempt_load
from utils.datasets import LoadImages
from utils.general import non_max_suppression, scale_coords, xyxy2xywh
from utils.torch_utils import select_device

# %% [markdown]
# ## Getting all the detections using our model and creating a dataframe

# %%
#Plot with just bounding box
def plot_one_box(x, image, color=None, label=None, line_thickness=3):
#     img = np.zeros_like(image, np.uint8)
    # Plots one bounding box on image img
    tl = line_thickness
    color = color or [random.randint(0, 255) for _ in range(3)]
    c1, c2 = (int(x[0]), int(x[1])), (int(x[2]), int(x[3]))
    cv2.rectangle(image, c1, c2, color, thickness=tl, lineType=cv2.LINE_AA)
    
    if label:
        tf = max(tl - 1, 1)  # font thickness
        t_size = cv2.getTextSize(label, 0, fontScale=tl / 3, thickness=tf)[0]
        c2 = c1[0] + t_size[0], c1[1] - t_size[1] - 3
        cv2.rectangle(image, c1, c2, color, -1, cv2.LINE_AA)  # filled
        cv2.putText(image, label, (c1[0], c1[1] - 2), 0, tl / 3, [225, 255, 255], thickness=tf, lineType=cv2.LINE_AA)
    
    return image

def detect(folder_name, results_out=False, save_dir = "data/try/result/", model_name = 'best.pt', 
           save_img=False, imgsz = 640, conf_th = 0.5, iou_th = 0.45):
    final_out = []
    
    # Initialize
    device = select_device('cpu')

    # Load model
    model = attempt_load(model_name, map_location=device)

    # Loading images
    dataset = LoadImages(folder_name, img_size=imgsz)

    # Get names and colors
    names = model.names
    colors = [(105, 40, 123), (25, 179, 255), (76, 20, 224)]
    
    t0 = time.time()
    
    final_df = pd.DataFrame(columns=['xmin', 'ymin', 'xmax', 'ymax', 'confidence', 'label', 'img_name'])
    label_dict = {0: 'unripe', 1: 'partially_ripe', 2: 'fully_ripe'}
    
    count = 0
    total_time = 0
    for p, img, im0s, _ in dataset:
        img = torch.from_numpy(img).to(device)
        img = img.float()
        img /= 255.0
        if img.ndimension() == 3:
            img = img.unsqueeze(0)

        # Inference
        t1 = time.time()
        with torch.no_grad(): 
            pred = model(img)[0]  # Calculating gradients would cause a GPU memory leak

        # Apply NMS
        pred = non_max_suppression(pred, conf_th, iou_th)
        t2 = time.time()
        
        # Process detections
        for i, det in enumerate(pred):  # detections per image
            s, im0, frame = '', im0s, getattr(dataset, 'frame', 0)

            p = Path(p)  # to Path

            gn = torch.tensor(im0.shape)[[1, 0, 1, 0]]  # normalization gain whwh
            if len(det):
                # Rescale boxes from img_size to im0 size
                det[:, :4] = scale_coords(img.shape[2:], det[:, :4], im0.shape).round()
                temp_df = pd.DataFrame(det.numpy(), columns=['xmin', 'ymin', 'xmax', 'ymax', 'confidence', 'label'])
                temp_df['label'] = temp_df['label'].apply(lambda x: label_dict[int(x)])
                temp_df['img_name'] = p.name

                # Print results
                for c in det[:, -1].unique():
                    n = (det[:, -1] == c).sum()  # detections per class
                    s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string

                # Write results
                for *xyxy, conf, cls in reversed(det):
                    xywh = (xyxy2xywh(torch.tensor(xyxy).view(1, 4)) / gn).view(-1).tolist()  # normalized xywh
                    line = (cls, *xywh, conf)
                    final_out.append(line)

                    # Add bbox to image
                    label = f'{names[int(cls)]} {conf:.2f}'
                    im0 = plot_one_box(xyxy, im0, label=label, color=colors[int(cls)], line_thickness=2)
                    
                if results_out:
                    cv2.imwrite(str(save_dir+'/'+ p.name), im0)
                    
                final_df = pd.concat([final_df, temp_df], ignore_index=True)
                
            # Print inference time of an image
            print(f'Image = {p.name}, {s}Done. ({(1E3 * (t2 - t1)):.1f}ms)')
            total_time+=t2-t1
            count+=1
        
    # Print inference time of all the images in total
    print(f'Done. ({time.time() - t0:.3f}s)')
    
    print(f"Average time of inference per image = {1E3 * total_time/count} ms")
    
    return final_df[['img_name', 'xmin', 'ymin', 'xmax', 'ymax', 'confidence', 'label']]

# %%
detect_df = detect('data/test/images/', save_dir = 'results/test/output/', conf_th = 0.5, iou_th = 0.45)

detect_df.to_csv('results/test/test.csv', index=False)
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# C:\Users\amita\anaconda3\envs\tf\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3191.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Image = 1003.png, 5 unripes, Done. (598.3ms)
# Image = 1008.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (531.2ms)
# Image = 101.png, 6 unripes, 1 fully ripe, Done. (533.3ms)
# Image = 1012.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (527.8ms)
# Image = 1038.png, 1 unripe, 1 partially ripe, Done. (531.3ms)
# Image = 1061.png, 2 unripes, 1 partially ripe, Done. (534.7ms)
# Image = 1091.png, 5 unripes, 2 partially ripes, Done. (529.8ms)
# Image = 1113.png, 3 unripes, 2 fully ripes, Done. (531.3ms)
# Image = 1148.png, 1 unripe, 1 partially ripe, Done. (532.5ms)
# Image = 1158.png, 7 unripes, 2 fully ripes, Done. (532.8ms)
# Image = 1161.png, 2 unripes, 1 partially ripe, 1 fully ripe, Done. (535.3ms)
# Image = 1169.png, 5 unripes, 1 partially ripe, Done. (534.0ms)
# Image = 1199.png, 2 unripes, 2 partially ripes, Done. (533.6ms)
# Image = 1206.png, 1 unripe, 3 partially ripes, Done. (533.2ms)
# Image = 1213.png, 6 unripes, 1 partially ripe, Done. (532.1ms)
# Image = 1224.png, 5 unripes, 1 partially ripe, Done. (538.9ms)
# Image = 1237.png, 2 unripes, 2 fully ripes, Done. (530.5ms)
# Image = 1246.png, 6 unripes, 1 partially ripe, 1 fully ripe, Done. (529.0ms)
# Image = 1248.png, 1 unripe, 1 fully ripe, Done. (527.0ms)
# Image = 1257.png, 3 unripes, 1 partially ripe, Done. (534.0ms)
# Image = 1289.png, 11 unripes, 1 partially ripe, 2 fully ripes, Done. (565.3ms)
# Image = 1297.png, 2 unripes, 1 partially ripe, Done. (582.7ms)
# Image = 13.png, 7 unripes, 2 partially ripes, Done. (551.0ms)
# Image = 1300.png, 6 unripes, 3 partially ripes, Done. (552.7ms)
# Image = 1327.png, 4 unripes, 1 partially ripe, Done. (563.8ms)
# Image = 1345.png, 4 unripes, 1 partially ripe, 1 fully ripe, Done. (568.6ms)
# Image = 1357.png, 1 unripe, 1 partially ripe, 2 fully ripes, Done. (570.5ms)
# Image = 1358.png, 6 unripes, 1 fully ripe, Done. (540.3ms)
# Image = 1366.png, 5 unripes, 1 partially ripe, Done. (575.9ms)
# Image = 137.png, 4 unripes, 1 fully ripe, Done. (545.7ms)
# Image = 1376.png, 6 unripes, 2 partially ripes, Done. (541.0ms)
# Image = 1411.png, 5 unripes, 1 partially ripe, Done. (532.7ms)
# Image = 1436.png, 5 unripes, 1 fully ripe, Done. (531.9ms)
# Image = 144.png, 4 unripes, 1 partially ripe, Done. (529.4ms)
# Image = 1446.png, 4 unripes, 1 fully ripe, Done. (532.6ms)
# Image = 1448.png, 1 unripe, 2 partially ripes, Done. (532.1ms)
# Image = 1450.png, 7 unripes, 3 partially ripes, 1 fully ripe, Done. (555.4ms)
# Image = 1463.png, 3 unripes, 1 partially ripe, Done. (559.6ms)
# Image = 1485.png, 4 unripes, 1 fully ripe, Done. (568.4ms)
# Image = 150.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (539.8ms)
# Image = 1509.png, 5 unripes, 2 partially ripes, Done. (579.8ms)
# Image = 1532.png, 6 unripes, 2 partially ripes, 1 fully ripe, Done. (552.0ms)
# Image = 1537.png, 1 partially ripe, Done. (565.0ms)
# Image = 1539.png, 2 partially ripes, 1 fully ripe, Done. (556.3ms)
# Image = 1543.png, 3 unripes, 1 partially ripe, Done. (574.3ms)
# Image = 1544.png, 4 unripes, 1 partially ripe, Done. (552.7ms)
# Image = 1559.png, 4 unripes, 1 partially ripe, 2 fully ripes, Done. (533.7ms)
# Image = 1567.png, 1 unripe, 2 fully ripes, Done. (533.0ms)
# Image = 1570.png, 5 unripes, 1 fully ripe, Done. (536.1ms)
# Image = 1595.png, 3 unripes, 1 partially ripe, 2 fully ripes, Done. (560.8ms)
# Image = 1616.png, 4 unripes, 1 partially ripe, Done. (563.4ms)
# Image = 1620.png, 7 unripes, 1 fully ripe, Done. (535.3ms)
# Image = 1622.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (537.1ms)
# Image = 1645.png, 1 unripe, 3 partially ripes, 1 fully ripe, Done. (539.7ms)
# Image = 1659.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (532.0ms)
# Image = 1666.png, 1 unripe, 1 partially ripe, Done. (534.7ms)
# Image = 1672.png, 6 unripes, 1 partially ripe, 2 fully ripes, Done. (536.7ms)
# Image = 168.png, 1 unripe, 1 partially ripe, Done. (553.6ms)
# Image = 1681.png, 1 unripe, 1 partially ripe, 1 fully ripe, Done. (563.4ms)
# Image = 170.png, 8 unripes, 2 partially ripes, 2 fully ripes, Done. (535.2ms)
# Image = 1713.png, 4 unripes, 1 partially ripe, 1 fully ripe, Done. (530.3ms)
# Image = 1728.png, 6 unripes, Done. (538.5ms)
# Image = 1738.png, 2 unripes, 1 fully ripe, Done. (534.4ms)
# Image = 1746.png, 3 unripes, 2 fully ripes, Done. (532.8ms)
# Image = 1756.png, 5 unripes, 1 fully ripe, Done. (535.5ms)
# Image = 1764.png, 2 unripes, 1 partially ripe, Done. (534.8ms)
# Image = 1765.png, 6 unripes, 1 partially ripe, 2 fully ripes, Done. (550.0ms)
# Image = 1769.png, 2 unripes, 1 fully ripe, Done. (534.6ms)
# Image = 1795.png, 2 unripes, 2 partially ripes, 1 fully ripe, Done. (554.1ms)
# Image = 18.png, 4 unripes, 1 partially ripe, Done. (538.6ms)
# Image = 1801.png, 10 unripes, 3 partially ripes, 2 fully ripes, Done. (537.2ms)
# Image = 1802.png, 4 unripes, 1 fully ripe, Done. (542.8ms)
# Image = 1812.png, 1 unripe, 3 partially ripes, Done. (552.9ms)
# Image = 1826.png, 2 unripes, 2 partially ripes, 2 fully ripes, Done. (533.0ms)
# Image = 1837.png, 5 unripes, 2 partially ripes, 1 fully ripe, Done. (534.7ms)
# Image = 1842.png, 3 unripes, 2 fully ripes, Done. (532.8ms)
# Image = 1851.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (552.9ms)
# Image = 1861.png, 5 unripes, 2 partially ripes, 1 fully ripe, Done. (567.7ms)
# Image = 1868.png, 3 unripes, 1 fully ripe, Done. (568.9ms)
# Image = 1869.png, 1 unripe, 2 partially ripes, 1 fully ripe, Done. (581.7ms)
# Image = 187.png, 5 unripes, 1 partially ripe, Done. (534.1ms)
# Image = 1876.png, 5 unripes, 1 fully ripe, Done. (561.2ms)
# Image = 1882.png, 5 unripes, 1 partially ripe, Done. (542.7ms)
# Image = 1892.png, 3 unripes, 2 partially ripes, 1 fully ripe, Done. (580.3ms)
# Image = 1900.png, 4 unripes, 2 partially ripes, 2 fully ripes, Done. (546.1ms)
# Image = 1904.png, 6 unripes, 1 partially ripe, Done. (536.3ms)
# Image = 1915.png, 6 unripes, 1 partially ripe, Done. (537.2ms)
# Image = 1917.png, 4 unripes, 1 fully ripe, Done. (551.6ms)
# Image = 1918.png, 5 unripes, 2 partially ripes, Done. (562.3ms)
# Image = 1931.png, 2 unripes, 1 fully ripe, Done. (539.7ms)
# Image = 1938.png, 7 unripes, 1 fully ripe, Done. (542.5ms)
# Image = 1953.png, 4 unripes, 1 partially ripe, 1 fully ripe, Done. (535.8ms)
# Image = 1954.png, 7 unripes, Done. (533.9ms)
# Image = 1955.png, 3 unripes, 1 fully ripe, Done. (532.9ms)
# Image = 1964.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (536.7ms)
# Image = 1968.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (577.5ms)
# Image = 198.png, 4 unripes, 1 fully ripe, Done. (545.6ms)
# Image = 2018.png, 2 unripes, 2 fully ripes, Done. (552.3ms)
# Image = 202.png, 2 unripes, 3 partially ripes, Done. (538.2ms)
# Image = 2021.png, 3 unripes, 2 partially ripes, 1 fully ripe, Done. (536.4ms)
# Image = 2024.png, 3 unripes, 1 partially ripe, 2 fully ripes, Done. (534.4ms)
# Image = 2030.png, 2 unripes, 1 partially ripe, 1 fully ripe, Done. (533.9ms)
# Image = 2039.png, 3 unripes, 1 fully ripe, Done. (536.4ms)
# Image = 2045.png, 2 unripes, 1 partially ripe, Done. (552.9ms)
# Image = 2049.png, 5 unripes, 1 fully ripe, Done. (539.2ms)
# Image = 208.png, 2 unripes, 1 partially ripe, Done. (530.9ms)
# Image = 2080.png, 5 unripes, Done. (531.3ms)
# Image = 2086.png, 4 unripes, 1 partially ripe, 1 fully ripe, Done. (553.1ms)
# Image = 2131.png, 5 unripes, 1 fully ripe, Done. (539.9ms)
# Image = 2166.png, 1 unripe, 1 partially ripe, 1 fully ripe, Done. (536.8ms)
# Image = 2179.png, 5 unripes, Done. (543.0ms)
# Image = 2186.png, 5 unripes, 2 partially ripes, 1 fully ripe, Done. (539.3ms)
# Image = 2187.png, 2 unripes, 2 fully ripes, Done. (548.8ms)
# Image = 2196.png, 10 unripes, 2 partially ripes, Done. (603.0ms)
# Image = 2203.png, 8 unripes, 2 partially ripes, Done. (549.7ms)
# Image = 2209.png, 4 unripes, 3 fully ripes, Done. (593.5ms)
# Image = 2210.png, 2 unripes, 1 partially ripe, 2 fully ripes, Done. (574.6ms)
# Image = 2215.png, 4 unripes, 1 partially ripe, Done. (574.2ms)
# Image = 222.png, 4 unripes, 1 fully ripe, Done. (558.9ms)
# Image = 2227.png, 2 unripes, 1 partially ripe, Done. (541.1ms)
# Image = 2229.png, 5 unripes, 2 partially ripes, 2 fully ripes, Done. (530.0ms)
# Image = 2243.png, 1 unripe, 1 partially ripe, 1 fully ripe, Done. (536.7ms)
# Image = 2248.png, 2 unripes, 1 partially ripe, Done. (531.5ms)
# Image = 2267.png, 3 unripes, 1 partially ripe, Done. (533.1ms)
# Image = 229.png, 8 unripes, 2 fully ripes, Done. (529.4ms)
# Image = 2293.png, 4 unripes, 1 fully ripe, Done. (536.8ms)
# Image = 2302.png, 6 unripes, 1 fully ripe, Done. (534.2ms)
# Image = 2303.png, 8 unripes, 1 partially ripe, Done. (539.3ms)
# Image = 2311.png, 6 unripes, Done. (535.0ms)
# Image = 232.png, 5 unripes, Done. (537.6ms)
# Image = 2324.png, 4 unripes, 2 fully ripes, Done. (536.3ms)
# Image = 2329.png, 4 unripes, 1 fully ripe, Done. (532.0ms)
# Image = 2336.png, 2 unripes, 1 partially ripe, Done. (528.0ms)
# Image = 2349.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (538.9ms)
# Image = 2369.png, 5 unripes, Done. (532.8ms)
# Image = 2385.png, 2 unripes, 1 partially ripe, Done. (530.4ms)
# Image = 2392.png, 2 unripes, 1 partially ripe, Done. (531.7ms)
# Image = 2397.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (535.7ms)
# Image = 2398.png, 4 unripes, 1 partially ripe, 2 fully ripes, Done. (534.9ms)
# Image = 24.png, 7 unripes, Done. (528.7ms)
# Image = 2411.png, 7 unripes, 3 partially ripes, Done. (538.4ms)
# Image = 2445.png, 2 unripes, 1 partially ripe, 1 fully ripe, Done. (537.8ms)
# Image = 2446.png, 2 unripes, 1 partially ripe, Done. (536.5ms)
# Image = 2447.png, 1 partially ripe, 1 fully ripe, Done. (533.2ms)
# Image = 2452.png, 3 unripes, 1 fully ripe, Done. (531.5ms)
# Image = 246.png, 4 unripes, 1 partially ripe, Done. (531.8ms)
# Image = 2470.png, 4 unripes, 1 fully ripe, Done. (534.8ms)
# Image = 248.png, 2 unripes, Done. (533.2ms)
# Image = 2482.png, 1 unripe, 1 partially ripe, Done. (534.7ms)
# Image = 2488.png, 6 unripes, 1 partially ripe, Done. (529.8ms)
# Image = 250.png, 6 unripes, 2 fully ripes, Done. (529.9ms)
# Image = 2517.png, 3 unripes, 3 partially ripes, 1 fully ripe, Done. (530.2ms)
# Image = 2531.png, 10 unripes, 1 partially ripe, Done. (530.7ms)
# Image = 2559.png, 3 unripes, 3 partially ripes, Done. (532.4ms)
# Image = 256.png, 5 unripes, 2 partially ripes, 1 fully ripe, Done. (532.2ms)
# Image = 2562.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (535.0ms)
# Image = 2564.png, 5 unripes, Done. (534.9ms)
# Image = 2568.png, 3 unripes, 1 partially ripe, 2 fully ripes, Done. (532.0ms)
# Image = 2569.png, 2 unripes, 2 partially ripes, Done. (534.4ms)
# Image = 2581.png, 1 partially ripe, 1 fully ripe, Done. (539.9ms)
# Image = 2592.png, 4 unripes, 3 partially ripes, 1 fully ripe, Done. (530.1ms)
# Image = 2594.png, 1 partially ripe, 1 fully ripe, Done. (530.5ms)
# Image = 2595.png, 2 unripes, 1 partially ripe, Done. (530.7ms)
# Image = 26.png, 2 partially ripes, Done. (536.6ms)
# Image = 2601.png, 1 unripe, 1 partially ripe, Done. (536.6ms)
# Image = 2610.png, 2 unripes, 1 fully ripe, Done. (540.1ms)
# Image = 2627.png, 2 unripes, 1 partially ripe, Done. (530.9ms)
# Image = 263.png, 1 partially ripe, 1 fully ripe, Done. (538.3ms)
# Image = 2644.png, 3 unripes, 1 partially ripe, Done. (541.2ms)
# Image = 2662.png, 5 unripes, 1 fully ripe, Done. (534.2ms)
# Image = 2667.png, 5 unripes, 1 fully ripe, Done. (535.8ms)
# Image = 2695.png, 1 partially ripe, 1 fully ripe, Done. (541.8ms)
# Image = 2703.png, 7 unripes, 1 partially ripe, 3 fully ripes, Done. (535.1ms)
# Image = 2705.png, 1 unripe, 1 partially ripe, 2 fully ripes, Done. (532.4ms)
# Image = 2706.png, 3 unripes, 1 fully ripe, Done. (532.3ms)
# Image = 2708.png, 3 unripes, 2 partially ripes, Done. (532.7ms)
# Image = 2719.png, 4 unripes, 2 partially ripes, Done. (537.2ms)
# Image = 2731.png, 5 unripes, 2 fully ripes, Done. (537.3ms)
# Image = 2739.png, 1 unripe, 3 partially ripes, Done. (529.7ms)
# Image = 2757.png, 5 unripes, 2 partially ripes, Done. (536.9ms)
# Image = 2762.png, 4 unripes, 2 partially ripes, Done. (537.7ms)
# Image = 2765.png, 1 partially ripe, Done. (537.6ms)
# Image = 2777.png, 4 unripes, 2 partially ripes, 1 fully ripe, Done. (536.8ms)
# Image = 2791.png, 2 partially ripes, 1 fully ripe, Done. (531.8ms)
# Image = 28.png, 7 unripes, 1 fully ripe, Done. (537.3ms)
# Image = 2807.png, 4 unripes, 2 partially ripes, Done. (581.8ms)
# Image = 2830.png, 4 unripes, 1 partially ripe, Done. (540.9ms)
# Image = 2834.png, 2 unripes, 2 partially ripes, 1 fully ripe, Done. (533.1ms)
# Image = 2841.png, 4 unripes, Done. (534.0ms)
# Image = 2845.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (529.4ms)
# Image = 285.png, 5 unripes, 2 partially ripes, Done. (539.6ms)
# Image = 2852.png, 6 unripes, 1 fully ripe, Done. (537.2ms)
# Image = 2857.png, 1 unripe, 2 partially ripes, 1 fully ripe, Done. (536.7ms)
# Image = 2896.png, 4 unripes, 1 fully ripe, Done. (533.1ms)
# Image = 2898.png, 4 unripes, 1 partially ripe, 1 fully ripe, Done. (531.2ms)
# Image = 2912.png, 4 unripes, 1 partially ripe, 1 fully ripe, Done. (540.3ms)
# Image = 2914.png, 1 unripe, 1 partially ripe, Done. (534.2ms)
# Image = 292.png, 2 unripes, 2 fully ripes, Done. (533.8ms)
# Image = 2945.png, 6 unripes, 1 partially ripe, Done. (537.7ms)
# Image = 2953.png, 4 unripes, 1 fully ripe, Done. (542.6ms)
# Image = 296.png, 2 unripes, 2 partially ripes, Done. (537.8ms)
# Image = 2964.png, 1 unripe, 1 partially ripe, 1 fully ripe, Done. (535.2ms)
# Image = 2969.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (544.3ms)
# Image = 2973.png, 6 unripes, 3 partially ripes, Done. (533.8ms)
# Image = 2994.png, 10 unripes, 2 partially ripes, Done. (527.6ms)
# Image = 30.png, 4 unripes, 1 fully ripe, Done. (543.5ms)
# Image = 302.png, 2 unripes, 2 partially ripes, 1 fully ripe, Done. (534.7ms)
# Image = 3025.png, 1 unripe, 1 partially ripe, 1 fully ripe, Done. (543.7ms)
# Image = 3027.png, 6 unripes, 1 partially ripe, 2 fully ripes, Done. (540.4ms)
# Image = 303.png, 2 unripes, 1 partially ripe, Done. (534.1ms)
# Image = 3044.png, 1 unripe, 2 partially ripes, 1 fully ripe, Done. (530.2ms)
# Image = 3046.png, 2 unripes, 1 partially ripe, 1 fully ripe, Done. (535.5ms)
# Image = 3048.png, 5 unripes, 2 partially ripes, Done. (534.3ms)
# Image = 3066.png, 4 unripes, 2 fully ripes, Done. (533.3ms)
# Image = 3068.png, 2 partially ripes, Done. (529.4ms)
# Image = 307.png, 3 unripes, 2 partially ripes, Done. (530.2ms)
# Image = 3072.png, 8 unripes, 2 partially ripes, Done. (534.4ms)
# Image = 3082.png, 5 unripes, 1 fully ripe, Done. (535.5ms)
# Image = 3083.png, 6 unripes, 1 partially ripe, 1 fully ripe, Done. (538.1ms)
# Image = 3092.png, 3 unripes, 1 partially ripe, Done. (534.9ms)
# Image = 3101.png, 1 partially ripe, 1 fully ripe, Done. (534.5ms)
# Image = 313.png, 1 partially ripe, Done. (537.5ms)
# Image = 314.png, 2 unripes, 1 partially ripe, 1 fully ripe, Done. (535.7ms)
# Image = 331.png, 6 unripes, Done. (533.4ms)
# Image = 344.png, 7 unripes, Done. (533.7ms)
# Image = 365.png, 11 unripes, 2 partially ripes, 2 fully ripes, Done. (550.9ms)
# Image = 370.png, 9 unripes, 2 partially ripes, 1 fully ripe, Done. (543.1ms)
# Image = 372.png, 2 unripes, 1 partially ripe, 1 fully ripe, Done. (535.0ms)
# Image = 383.png, 1 unripe, 1 partially ripe, 1 fully ripe, Done. (535.1ms)
# Image = 402.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (526.0ms)
# Image = 409.png, 4 unripes, 1 partially ripe, Done. (537.5ms)
# Image = 422.png, 1 unripe, 1 partially ripe, Done. (537.9ms)
# Image = 424.png, 6 unripes, 1 partially ripe, 1 fully ripe, Done. (535.6ms)
# Image = 446.png, 1 unripe, 1 partially ripe, 2 fully ripes, Done. (534.5ms)
# Image = 452.png, 1 unripe, 1 partially ripe, Done. (533.7ms)
# Image = 453.png, 12 unripes, 2 partially ripes, Done. (536.6ms)
# Image = 463.png, 3 unripes, Done. (539.2ms)
# Image = 469.png, 1 partially ripe, 1 fully ripe, Done. (535.3ms)
# Image = 473.png, 4 unripes, 1 partially ripe, 2 fully ripes, Done. (541.6ms)
# Image = 476.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (535.5ms)
# Image = 478.png, 4 unripes, 1 partially ripe, Done. (541.3ms)
# Image = 483.png, 1 unripe, 1 partially ripe, Done. (536.0ms)
# Image = 491.png, 2 unripes, 1 partially ripe, 1 fully ripe, Done. (536.8ms)
# Image = 50.png, 7 unripes, 1 partially ripe, Done. (531.1ms)
# Image = 51.png, 3 unripes, 1 partially ripe, Done. (534.8ms)
# Image = 519.png, 9 unripes, 1 partially ripe, Done. (535.1ms)
# Image = 53.png, 3 unripes, 1 partially ripe, 1 fully ripe, Done. (533.5ms)
# Image = 551.png, 2 unripes, 1 partially ripe, Done. (585.7ms)
# Image = 553.png, 4 unripes, 1 partially ripe, Done. (558.2ms)
# Image = 558.png, 2 unripes, 2 partially ripes, 2 fully ripes, Done. (583.5ms)
# Image = 559.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (556.7ms)
# Image = 560.png, 5 unripes, Done. (528.7ms)
# Image = 564.png, 2 unripes, 1 partially ripe, Done. (538.0ms)
# Image = 570.png, 4 unripes, 1 partially ripe, Done. (538.3ms)
# Image = 596.png, 5 unripes, 1 partially ripe, Done. (532.9ms)
# Image = 597.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (539.6ms)
# Image = 615.png, 2 unripes, 2 partially ripes, 1 fully ripe, Done. (535.7ms)
# Image = 629.png, 6 unripes, 2 partially ripes, Done. (535.4ms)
# Image = 632.png, 5 unripes, 1 fully ripe, Done. (533.6ms)
# Image = 635.png, 3 unripes, 2 partially ripes, 3 fully ripes, Done. (533.7ms)
# Image = 662.png, 7 unripes, 1 partially ripe, Done. (537.3ms)
# Image = 668.png, 5 unripes, 2 partially ripes, 1 fully ripe, Done. (537.2ms)
# Image = 671.png, 3 unripes, 2 partially ripes, 1 fully ripe, Done. (543.0ms)
# Image = 675.png, 8 unripes, 1 partially ripe, Done. (533.5ms)
# Image = 686.png, 3 unripes, 2 partially ripes, Done. (574.3ms)
# Image = 690.png, 4 unripes, Done. (568.8ms)
# Image = 693.png, 2 unripes, 1 fully ripe, Done. (533.1ms)
# Image = 697.png, 6 unripes, 2 partially ripes, Done. (537.7ms)
# Image = 699.png, 3 unripes, 1 partially ripe, Done. (537.6ms)
# Image = 703.png, 3 unripes, 1 partially ripe, Done. (533.1ms)
# Image = 716.png, 10 unripes, Done. (541.0ms)
# Image = 738.png, 4 unripes, Done. (538.8ms)
# Image = 75.png, 5 unripes, 3 partially ripes, 2 fully ripes, Done. (526.0ms)
# Image = 750.png, 8 unripes, 1 partially ripe, Done. (536.0ms)
# Image = 76.png, 3 unripes, 1 partially ripe, Done. (540.5ms)
# Image = 761.png, 8 unripes, 1 fully ripe, Done. (537.9ms)
# Image = 769.png, 2 unripes, 1 fully ripe, Done. (542.0ms)
# Image = 798.png, 1 unripe, 2 fully ripes, Done. (536.4ms)
# Image = 810.png, 6 unripes, 2 partially ripes, 1 fully ripe, Done. (538.9ms)
# Image = 812.png, 5 unripes, 1 partially ripe, 1 fully ripe, Done. (532.5ms)
# Image = 818.png, 3 unripes, Done. (537.5ms)
# Image = 827.png, 5 unripes, 5 partially ripes, Done. (538.3ms)
# Image = 832.png, 7 unripes, 1 partially ripe, 1 fully ripe, Done. (531.4ms)
# Image = 833.png, 1 fully ripe, Done. (533.1ms)
# Image = 846.png, 6 unripes, 1 partially ripe, Done. (534.5ms)
# Image = 862.png, 5 unripes, 1 partially ripe, Done. (533.0ms)
# Image = 868.png, 4 unripes, 1 partially ripe, Done. (528.9ms)
# Image = 87.png, 2 partially ripes, Done. (536.1ms)
# Image = 876.png, 7 unripes, 1 partially ripe, Done. (535.4ms)
# Image = 882.png, 5 unripes, 2 partially ripes, 1 fully ripe, Done. (535.7ms)
# Image = 897.png, 5 unripes, 2 fully ripes, Done. (535.0ms)
# Image = 910.png, 5 unripes, 2 partially ripes, 2 fully ripes, Done. (534.0ms)
# Image = 921.png, 3 unripes, 3 fully ripes, Done. (535.6ms)
# Image = 934.png, 2 partially ripes, Done. (536.3ms)
# Image = 939.png, 3 unripes, 1 partially ripe, Done. (533.0ms)
# Image = 943.png, 4 unripes, 1 fully ripe, Done. (536.3ms)
# Image = 960.png, 2 unripes, 1 partially ripe, Done. (537.4ms)
# Image = 968.png, 1 unripe, 2 fully ripes, Done. (537.8ms)
# Image = 970.png, 3 unripes, 1 partially ripe, Done. (534.5ms)
# Image = 971.png, 3 unripes, 1 partially ripe, Done. (535.5ms)
# Done. (173.297s)
# Average time of inference per image = 540.5376482009888 ms

# %%
detect_df
# Out:
#       img_name   xmin   ymin   xmax   ymax  confidence           label
# 0     1003.png  738.0  379.0  805.0  466.0    0.974735          unripe
# 1     1003.png  590.0  362.0  697.0  531.0    0.952862          unripe
# 2     1003.png    1.0  199.0   74.0  314.0    0.942174          unripe
# 3     1003.png  396.0  379.0  466.0  479.0    0.919797          unripe
# 4     1003.png  221.0  344.0  256.0  378.0    0.910763          unripe
# ...        ...    ...    ...    ...    ...         ...             ...
# 1660   970.png    1.0  263.0   45.0  306.0    0.941539          unripe
# 1661   971.png  590.0  210.0  685.0  306.0    0.928950          unripe
# 1662   971.png  546.0  291.0  702.0  433.0    0.818956  partially_ripe
# 1663   971.png   94.0  712.0  196.0  754.0    0.785696          unripe
# 1664   971.png  601.0   16.0  662.0   80.0    0.553303          unripe
#
# [1665 rows x 7 columns]

# %% [markdown]
# ## Creating dataframe of original bounding boxes we get from Annotations

# %%
# Create an empty dataframe
df = pd.DataFrame(columns=['img_name', 'xmin', 'ymin', 'xmax', 'ymax', 'label'])

# Set the path to the directory containing the .txt files
txt_path = 'data/test/labels/'
img_path = 'data/test/images/'

label_dict = {0: 'unripe', 1: 'partially_ripe', 2: 'fully_ripe'}

img_names, x_mins, y_mins, x_maxs, y_maxs, labels = [], [], [], [], [], []

# Iterate through the files in the directory
for file in os.listdir(txt_path):
    # Open the file
    
    img = cv2.imread(os.path.join(img_path, file.replace('.txt', '.png')))
    
    with open(os.path.join(txt_path, file), 'r') as f:
        # Read the contents of the file
        contents = f.read()
        # Split the contents by newline to get a list of strings
        lines = contents.split('\n')
        # Iterate through the lines
        for line in lines:
            # Split the line by space to get a list of values
            values = line.split(' ')
        
            if len(values) > 1:
                x = int(float(values[1]) * img.shape[1])
                y = int(float(values[2]) * img.shape[0])
                w = int(float(values[3]) * img.shape[1])
                h = int(float(values[4]) * img.shape[0])

                xmin = np.clip(x - w//2, 0, None)
                ymin = np.clip(y - h//2, 0, None)
                xmax = np.clip(x + w//2, None, img.shape[1])
                ymax = np.clip(y + h//2, None, img.shape[0])
                
                img_names.append(file.replace('.txt', '.png'))
                x_mins.append(xmin)
                y_mins.append(ymin)
                x_maxs.append(xmax)
                y_maxs.append(ymax)
                labels.append(label_dict[int(values[0])])

# Display the dataframe
true_df = pd.DataFrame({'img_name': img_names, 'xmin':x_mins, 'ymin':y_mins, 'xmax':x_maxs, 'ymax':y_maxs, 'label':labels})
true_df.to_csv('results/test/test_ground_truth.csv', index=False)

# %%
true_df
# Out:
#       img_name  xmin  ymin  xmax  ymax       label
# 0     1003.png   914     0   936    10  fully_ripe
# 1     1003.png   880     0   914    10      unripe
# 2     1003.png   694     0   720    18  fully_ripe
# 3     1003.png   738   379   804   465      unripe
# 4     1003.png   588   364   698   532      unripe
# ...        ...   ...   ...   ...   ...         ...
# 1706   970.png     0   260    45   306      unripe
# 1707   971.png   545   290   703   434  fully_ripe
# 1708   971.png   590   206   684   306      unripe
# 1709   971.png   603    15   661    77      unripe
# 1710   971.png   113   715   189   755      unripe
#
# [1711 rows x 6 columns]

# %% [markdown]
# ## Code to create .txt file for mAP calculation

# %%
true_df = pd.read_csv('results/test/test_ground_truth.csv')
detect_df = pd.read_csv('results/test/test.csv')

# %%
def remove_txt_files(folder):
    import fnmatch
    for root, dirs, files in os.walk(folder):
        for filename in fnmatch.filter(files, '*.txt'):
            os.unlink(os.path.join(root, filename))

# Test the function
remove_txt_files('mAP/input/')


for val in true_df['img_name'].unique():
    f_name = val.replace('.png', '.txt')
    
    gt_path = os.path.join('mAP', 'input', 'ground-truth', f_name)
    gt_temp = true_df[true_df['img_name']==val]
    np.savetxt(gt_path, gt_temp[['label', 'xmin', 'ymin', 'xmax', 'ymax']].values, fmt='%s')

    dt_path = os.path.join('mAP', 'input', 'detection-results', f_name)
    dt_temp = detect_df[detect_df['img_name']==val]
    np.savetxt(dt_path, dt_temp[['label', 'confidence', 'xmin', 'ymin', 'xmax', 'ymax']].values, fmt='%s')

# %%
# !python mAP/main.py
# Out:
# 86.64% = fully_ripe AP
# 87.95% = partially_ripe AP
# 93.04% = unripe AP
# mAP = 89.21%
# Label wise results saved in the results.csv inside mAP folder

# %%
detections_map = pd.read_csv('mAP/result.csv')

# %%
detections_map
# Out:
#            Labels  Ground Truth Count  Detected Correctly  False Positive  \
# 0      fully_ripe                 204                 187              39
# 1  partially_ripe                 308                 284              51
# 2          unripe                1199                1139              53
#
#    Not Detected
# 0            17
# 1            24
# 2            60
